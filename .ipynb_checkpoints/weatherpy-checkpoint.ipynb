# %% [markdown]
# # Analysis:
#
# 1. There appears to be a relatively strong correlation bewteen latitude and temperature. The lower latitudes have higher temperatures and the higher latitudes have lower temperatures.  The temperature seems to peek at 20 degrees, this may be due the fact that most major deserts are at this lattitude.
#
# 2. There only seems to be a slight correlation between lattitude and humidity.
#
# 3. Neither windspeed nor cloudiness showed correlation with lattitude.  Cloudiness has distinct bands at certain points 20%, 40%, 75%.  These are likely human reported numbers based on best guess observations.

# %%
from citipy import citipy
from random import uniform
import pandas as pd
import numpy as np
import requests
from requests.exceptions import HTTPError
import matplotlib.pyplot as plt
from datetime import datetime
import time
from api_config import w_key

# how many cities to sample 
number_of_cities = 500

# set up Open Weather API URL
# q={city name},{country code}&APPID={APIKEY}
# set units to desired key, default is kelvin
weather_url="https://api.openweathermap.org/data/2.5/weather"
w_params =  {"q" : "",
             "units" : "imperial",
            "APIKEY" : w_key}

# %%
# dictionary to collect 500 unique cities
cities_dict = {} 

# loop to add 500 cities to cities_dict
while len(cities_dict) < number_of_cities + 5 + number_of_cities*.25: # add 25% to ammount gathered to allow for city not found errors 

    # generate random longitude and latitude
    long_rand = uniform(-180,180)
    lat_rand = uniform(-90, 90)

    # use citypy to get name and country of nearest city, use variables for easy code reading
    city = citipy.nearest_city(lat_rand, long_rand)
    city_name = city.city_name
    city_country = city.country_code

    # add to dictionary for ease of selecting unique values, this will not allow same city name different country
    # but is an easy method to ensure unique entries in one pass
    cities_dict[city_name] = city.country_code

# dictionary to dataframe to store city information
cities = pd.DataFrame.from_dict(cities_dict, orient='index') 
cities.reset_index(inplace=True)
cities.columns = ['City','Country']
cities['Temperature']=""
cities['Humidity']=""
cities['Cloudiness']=""
cities['Wind Speed']=""
cities['Latitude']=""
cities['Longitude']=""
cities['Time']=""

# %%
# check if errors occured
skipped = 0

# loop through dataframe get params to set for weather lookup
for index, row in cities.iterrows():

    # assign params to query string to send to open weather API
    w_params['q'] = f"{row['City']},{row['Country']}" 
    
    try:
        # collect weather data per city from Open Weather API
        w_response = requests.post(weather_url, params=w_params)
        w_response_data = w_response.json()
        w_response.raise_for_status()
    except HTTPError as http_err:
        # print(f'HTTP error occurred: {http_err}')
        skipped = skipped + 1
        print(f"{w_response_data['message']} : {row['City']}, {row['Country']} was skipped.")
    except Exception as err:
        # print(f'Other error occurred: {err}')
        skipped = skipped + 1
        print(f"{err} : {row['City']}, {row['Country']} was skipped.")
    else:
        row['Temperature']=w_response_data["main"]["temp_max"]
        row['Humidity']=w_response_data["main"]["humidity"]
        row['Cloudiness']=w_response_data["clouds"]["all"]
        row['Wind Speed']=w_response_data["wind"]["speed"]
        row['Latitude']=w_response_data["coord"]["lat"]
        row['Longitude']=w_response_data["coord"]["lon"]
        row['Time']=w_response_data["dt"]
        #print(w_response_data)
        #print(w_response_data["main"]["temp"])
        print(f"{w_response_data['id']} : {row['City']}, {row['Country']}, ({weather_url}?q={w_params['q']}&units={w_params['units']}) has been processed")
    
    # wait 1+ second to exceed 60 per minute rate limit of API
    time.sleep(1.01)

if skipped>0:
    cities.replace('', np.nan, inplace=True)
    cities=cities.dropna()
    print("________________________________________________________________")
    print(f"{skipped} rows dropped due to error(s) retrieving data. {len(cities)} cities remaining.")
    

if len(cities) < number_of_cities:
    print("________________________________________________________________")
    print(f"Error: You requested data for {number_of_cities} but only data for {len(cities)} cities was retrieved.")
              
print("________________________________________________________________")
print(f"Weather data has been loaded for {len(cities)} cities of {number_of_cities} cities required.")
# Out:
# 3833367 : ushuaia, ar, (https://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial) has been processed
# city not found : toliary, mg was skipped.
# 3366880 : hermanus, za, (https://api.openweathermap.org/data/2.5/weather?q=hermanus,za&units=imperial) has been processed
# 5848280 : kapaa, us, (https://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial) has been processed
# 1784055 : zhuanghe, cn, (https://api.openweathermap.org/data/2.5/weather?q=zhuanghe,cn&units=imperial) has been processed
# 964432 : port alfred, za, (https://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=imperial) has been processed
# city not found : mataura, pf was skipped.
# 3369157 : cape town, za, (https://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=imperial) has been processed
# 4030556 : rikitea, pf, (https://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial) has been processed
# 2618795 : klaksvik, fo, (https://api.openweathermap.org/data/2.5/weather?q=klaksvik,fo&units=imperial) has been processed
# 5859699 : college, us, (https://api.openweathermap.org/data/2.5/weather?q=college,us&units=imperial) has been processed
# 157429 : kilindoni, tz, (https://api.openweathermap.org/data/2.5/weather?q=kilindoni,tz&units=imperial) has been processed
# 2017155 : saskylakh, ru, (https://api.openweathermap.org/data/2.5/weather?q=saskylakh,ru&units=imperial) has been processed
# city not found : codrington, ag was skipped.
# 2075265 : busselton, au, (https://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=imperial) has been processed
# 3421765 : nanortalik, gl, (https://api.openweathermap.org/data/2.5/weather?q=nanortalik,gl&units=imperial) has been processed
# 4034551 : faanui, pf, (https://api.openweathermap.org/data/2.5/weather?q=faanui,pf&units=imperial) has been processed
# 3863379 : mar del plata, ar, (https://api.openweathermap.org/data/2.5/weather?q=mar del plata,ar&units=imperial) has been processed
# 2163355 : hobart, au, (https://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=imperial) has been processed
# 4035715 : avarua, ck, (https://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=imperial) has been processed
# 5880568 : bethel, us, (https://api.openweathermap.org/data/2.5/weather?q=bethel,us&units=imperial) has been processed
# 3831208 : qaanaaq, gl, (https://api.openweathermap.org/data/2.5/weather?q=qaanaaq,gl&units=imperial) has been processed
# 3629710 : puerto ayacucho, ve, (https://api.openweathermap.org/data/2.5/weather?q=puerto ayacucho,ve&units=imperial) has been processed
# 6165406 : thompson, ca, (https://api.openweathermap.org/data/2.5/weather?q=thompson,ca&units=imperial) has been processed
# 1106677 : bambous virieux, mu, (https://api.openweathermap.org/data/2.5/weather?q=bambous virieux,mu&units=imperial) has been processed
# 2110227 : butaritari, ki, (https://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&units=imperial) has been processed
# 2025286 : chuguyevka, ru, (https://api.openweathermap.org/data/2.5/weather?q=chuguyevka,ru&units=imperial) has been processed
# 3532499 : tecoanapa, mx, (https://api.openweathermap.org/data/2.5/weather?q=tecoanapa,mx&units=imperial) has been processed
# 1493110 : samus, ru, (https://api.openweathermap.org/data/2.5/weather?q=samus,ru&units=imperial) has been processed
# city not found : vila, vu was skipped.
# 2527089 : tiznit, ma, (https://api.openweathermap.org/data/2.5/weather?q=tiznit,ma&units=imperial) has been processed
# 3424607 : tasiilaq, gl, (https://api.openweathermap.org/data/2.5/weather?q=tasiilaq,gl&units=imperial) has been processed
# 5983720 : iqaluit, ca, (https://api.openweathermap.org/data/2.5/weather?q=iqaluit,ca&units=imperial) has been processed
# 3374346 : ponta do sol, cv, (https://api.openweathermap.org/data/2.5/weather?q=ponta do sol,cv&units=imperial) has been processed
# 2126199 : cherskiy, ru, (https://api.openweathermap.org/data/2.5/weather?q=cherskiy,ru&units=imperial) has been processed
# 3652764 : puerto ayora, ec, (https://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial) has been processed
# 5223593 : newport, us, (https://api.openweathermap.org/data/2.5/weather?q=newport,us&units=imperial) has been processed
# city not found : lasa, cn was skipped.
# 5905616 : bonnyville, ca, (https://api.openweathermap.org/data/2.5/weather?q=bonnyville,ca&units=imperial) has been processed
# 2234663 : batouri, cm, (https://api.openweathermap.org/data/2.5/weather?q=batouri,cm&units=imperial) has been processed
# 1795857 : shaowu, cn, (https://api.openweathermap.org/data/2.5/weather?q=shaowu,cn&units=imperial) has been processed
# 2122389 : ossora, ru, (https://api.openweathermap.org/data/2.5/weather?q=ossora,ru&units=imperial) has been processed
# 107304 : buraydah, sa, (https://api.openweathermap.org/data/2.5/weather?q=buraydah,sa&units=imperial) has been processed
# 5855927 : hilo, us, (https://api.openweathermap.org/data/2.5/weather?q=hilo,us&units=imperial) has been processed
# 3372707 : ribeira grande, pt, (https://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&units=imperial) has been processed
# 2525767 : agira, it, (https://api.openweathermap.org/data/2.5/weather?q=agira,it&units=imperial) has been processed
# 3573197 : hamilton, bm, (https://api.openweathermap.org/data/2.5/weather?q=hamilton,bm&units=imperial) has been processed
# 3116689 : miranda de ebro, es, (https://api.openweathermap.org/data/2.5/weather?q=miranda de ebro,es&units=imperial) has been processed
# 2172797 : cairns, au, (https://api.openweathermap.org/data/2.5/weather?q=cairns,au&units=imperial) has been processed
# city not found : samusu, ws was skipped.
# 4252975 : barrow, us, (https://api.openweathermap.org/data/2.5/weather?q=barrow,us&units=imperial) has been processed
# city not found : teluk nibung, id was skipped.
# 1015776 : bredasdorp, za, (https://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=imperial) has been processed
# 967106 : oudtshoorn, za, (https://api.openweathermap.org/data/2.5/weather?q=oudtshoorn,za&units=imperial) has been processed
# 509483 : pinega, ru, (https://api.openweathermap.org/data/2.5/weather?q=pinega,ru&units=imperial) has been processed
# 6096551 : pangnirtung, ca, (https://api.openweathermap.org/data/2.5/weather?q=pangnirtung,ca&units=imperial) has been processed
# city not found : ondorhaan, mn was skipped.
# 4407665 : kodiak, us, (https://api.openweathermap.org/data/2.5/weather?q=kodiak,us&units=imperial) has been processed
# 2121025 : srednekolymsk, ru, (https://api.openweathermap.org/data/2.5/weather?q=srednekolymsk,ru&units=imperial) has been processed
# 2729907 : longyearbyen, sj, (https://api.openweathermap.org/data/2.5/weather?q=longyearbyen,sj&units=imperial) has been processed
# 1800764 : mengcheng, cn, (https://api.openweathermap.org/data/2.5/weather?q=mengcheng,cn&units=imperial) has been processed
# city not found : malakal, sd was skipped.
# 2411397 : georgetown, sh, (https://api.openweathermap.org/data/2.5/weather?q=georgetown,sh&units=imperial) has been processed
# 1006984 : east london, za, (https://api.openweathermap.org/data/2.5/weather?q=east london,za&units=imperial) has been processed
# 286621 : salalah, om, (https://api.openweathermap.org/data/2.5/weather?q=salalah,om&units=imperial) has been processed
# 1490256 : talnakh, ru, (https://api.openweathermap.org/data/2.5/weather?q=talnakh,ru&units=imperial) has been processed
# 2409914 : bonthe, sl, (https://api.openweathermap.org/data/2.5/weather?q=bonthe,sl&units=imperial) has been processed
# city not found : mys shmidta, ru was skipped.
# 3837213 : rivadavia, ar, (https://api.openweathermap.org/data/2.5/weather?q=rivadavia,ar&units=imperial) has been processed
# 1265515 : kurgunta, in, (https://api.openweathermap.org/data/2.5/weather?q=kurgunta,in&units=imperial) has been processed
# 2208248 : kaitangata, nz, (https://api.openweathermap.org/data/2.5/weather?q=kaitangata,nz&units=imperial) has been processed
# city not found : grand river south east, mu was skipped.
# 1795095 : mingshui, cn, (https://api.openweathermap.org/data/2.5/weather?q=mingshui,cn&units=imperial) has been processed
# city not found : taolanaro, mg was skipped.
# 1233369 : negombo, lk, (https://api.openweathermap.org/data/2.5/weather?q=negombo,lk&units=imperial) has been processed
# 2206939 : bluff, nz, (https://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=imperial) has been processed
# 935215 : saint-philippe, re, (https://api.openweathermap.org/data/2.5/weather?q=saint-philippe,re&units=imperial) has been processed
# 3874787 : punta arenas, cl, (https://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial) has been processed
# 4020109 : atuona, pf, (https://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial) has been processed
# 2317397 : bandundu, cd, (https://api.openweathermap.org/data/2.5/weather?q=bandundu,cd&units=imperial) has been processed
# 174448 : abu kamal, sy, (https://api.openweathermap.org/data/2.5/weather?q=abu kamal,sy&units=imperial) has been processed
# 556268 : ostrovnoy, ru, (https://api.openweathermap.org/data/2.5/weather?q=ostrovnoy,ru&units=imperial) has been processed
# 2071860 : esperance, au, (https://api.openweathermap.org/data/2.5/weather?q=esperance,au&units=imperial) has been processed
# 2077895 : alice springs, au, (https://api.openweathermap.org/data/2.5/weather?q=alice springs,au&units=imperial) has been processed
# city not found : airai, pw was skipped.
# 3840300 : presidencia roque saenz pena, ar, (https://api.openweathermap.org/data/2.5/weather?q=presidencia roque saenz pena,ar&units=imperial) has been processed
# 1282256 : hithadhoo, mv, (https://api.openweathermap.org/data/2.5/weather?q=hithadhoo,mv&units=imperial) has been processed
# 3443061 : chuy, uy, (https://api.openweathermap.org/data/2.5/weather?q=chuy,uy&units=imperial) has been processed
# 3572627 : cockburn town, bs, (https://api.openweathermap.org/data/2.5/weather?q=cockburn town,bs&units=imperial) has been processed
# 4004293 : ixtapa, mx, (https://api.openweathermap.org/data/2.5/weather?q=ixtapa,mx&units=imperial) has been processed
# 3449747 : santa vitoria do palmar, br, (https://api.openweathermap.org/data/2.5/weather?q=santa vitoria do palmar,br&units=imperial) has been processed
# city not found : kuche, cn was skipped.
# 161616 : balkanabat, tm, (https://api.openweathermap.org/data/2.5/weather?q=balkanabat,tm&units=imperial) has been processed
# 3404558 : cabedelo, br, (https://api.openweathermap.org/data/2.5/weather?q=cabedelo,br&units=imperial) has been processed
# 3584003 : puerto el triunfo, sv, (https://api.openweathermap.org/data/2.5/weather?q=puerto el triunfo,sv&units=imperial) has been processed
# city not found : illoqqortoormiut, gl was skipped.
# 6050066 : la ronge, ca, (https://api.openweathermap.org/data/2.5/weather?q=la ronge,ca&units=imperial) has been processed
# 2129072 : kushiro, jp, (https://api.openweathermap.org/data/2.5/weather?q=kushiro,jp&units=imperial) has been processed
# 3370903 : jamestown, sh, (https://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=imperial) has been processed
# 3466165 : cidreira, br, (https://api.openweathermap.org/data/2.5/weather?q=cidreira,br&units=imperial) has been processed
# 1244926 : hambantota, lk, (https://api.openweathermap.org/data/2.5/weather?q=hambantota,lk&units=imperial) has been processed
# 359792 : aswan, eg, (https://api.openweathermap.org/data/2.5/weather?q=aswan,eg&units=imperial) has been processed
# 2159220 : mackay, au, (https://api.openweathermap.org/data/2.5/weather?q=mackay,au&units=imperial) has been processed
# 6167817 : torbay, ca, (https://api.openweathermap.org/data/2.5/weather?q=torbay,ca&units=imperial) has been processed
# 2267254 : lagoa, pt, (https://api.openweathermap.org/data/2.5/weather?q=lagoa,pt&units=imperial) has been processed
# 1264976 : leh, in, (https://api.openweathermap.org/data/2.5/weather?q=leh,in&units=imperial) has been processed
# 2126123 : chokurdakh, ru, (https://api.openweathermap.org/data/2.5/weather?q=chokurdakh,ru&units=imperial) has been processed
# 2022572 : khatanga, ru, (https://api.openweathermap.org/data/2.5/weather?q=khatanga,ru&units=imperial) has been processed
# 964420 : port elizabeth, za, (https://api.openweathermap.org/data/2.5/weather?q=port elizabeth,za&units=imperial) has been processed
# 1623197 : tual, id, (https://api.openweathermap.org/data/2.5/weather?q=tual,id&units=imperial) has been processed
# city not found : mizpe ramon, il was skipped.
# 1052373 : beira, mz, (https://api.openweathermap.org/data/2.5/weather?q=beira,mz&units=imperial) has been processed
# city not found : marcona, pe was skipped.
# 3985168 : san patricio, mx, (https://api.openweathermap.org/data/2.5/weather?q=san patricio,mx&units=imperial) has been processed
# 707489 : ivankiv, ua, (https://api.openweathermap.org/data/2.5/weather?q=ivankiv,ua&units=imperial) has been processed
# 5942576 : dresden, ca, (https://api.openweathermap.org/data/2.5/weather?q=dresden,ca&units=imperial) has been processed
# 5563839 : fortuna, us, (https://api.openweathermap.org/data/2.5/weather?q=fortuna,us&units=imperial) has been processed
# 2112802 : hasaki, jp, (https://api.openweathermap.org/data/2.5/weather?q=hasaki,jp&units=imperial) has been processed
# 1633419 : padang, id, (https://api.openweathermap.org/data/2.5/weather?q=padang,id&units=imperial) has been processed
# 1170951 : mansehra, pk, (https://api.openweathermap.org/data/2.5/weather?q=mansehra,pk&units=imperial) has been processed
# 2186111 : ngunguru, nz, (https://api.openweathermap.org/data/2.5/weather?q=ngunguru,nz&units=imperial) has been processed
# 934649 : cap malheureux, mu, (https://api.openweathermap.org/data/2.5/weather?q=cap malheureux,mu&units=imperial) has been processed
# 3115824 : muros, es, (https://api.openweathermap.org/data/2.5/weather?q=muros,es&units=imperial) has been processed
# 4267710 : sitka, us, (https://api.openweathermap.org/data/2.5/weather?q=sitka,us&units=imperial) has been processed
# city not found : jujuy, ar was skipped.
# city not found : avera, pf was skipped.
# city not found : sorvag, fo was skipped.
# city not found : tunduru, tz was skipped.
# 2015306 : tiksi, ru, (https://api.openweathermap.org/data/2.5/weather?q=tiksi,ru&units=imperial) has been processed
# 3883457 : lebu, cl, (https://api.openweathermap.org/data/2.5/weather?q=lebu,cl&units=imperial) has been processed
# 1810845 : fuyang, cn, (https://api.openweathermap.org/data/2.5/weather?q=fuyang,cn&units=imperial) has been processed
# 2170581 : coolum beach, au, (https://api.openweathermap.org/data/2.5/weather?q=coolum beach,au&units=imperial) has been processed
# 2077963 : albany, au, (https://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial) has been processed
# 5418104 : cortez, us, (https://api.openweathermap.org/data/2.5/weather?q=cortez,us&units=imperial) has been processed
# 3461465 : iguape, br, (https://api.openweathermap.org/data/2.5/weather?q=iguape,br&units=imperial) has been processed
# 3662927 : pauini, br, (https://api.openweathermap.org/data/2.5/weather?q=pauini,br&units=imperial) has been processed
# 2636790 : stornoway, gb, (https://api.openweathermap.org/data/2.5/weather?q=stornoway,gb&units=imperial) has been processed
# 116406 : semirom, ir, (https://api.openweathermap.org/data/2.5/weather?q=semirom,ir&units=imperial) has been processed
# 2016307 : solnechnyy, ru, (https://api.openweathermap.org/data/2.5/weather?q=solnechnyy,ru&units=imperial) has been processed
# 5861897 : fairbanks, us, (https://api.openweathermap.org/data/2.5/weather?q=fairbanks,us&units=imperial) has been processed
# 6170031 : tuktoyaktuk, ca, (https://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=imperial) has been processed
# 2155472 : newcastle, au, (https://api.openweathermap.org/data/2.5/weather?q=newcastle,au&units=imperial) has been processed
# 2074865 : carnarvon, au, (https://api.openweathermap.org/data/2.5/weather?q=carnarvon,au&units=imperial) has been processed
# 371745 : kutum, sd, (https://api.openweathermap.org/data/2.5/weather?q=kutum,sd&units=imperial) has been processed
# 3355672 : luderitz, na, (https://api.openweathermap.org/data/2.5/weather?q=luderitz,na&units=imperial) has been processed
# 2063042 : port hedland, au, (https://api.openweathermap.org/data/2.5/weather?q=port hedland,au&units=imperial) has been processed
# 2120591 : tilichiki, ru, (https://api.openweathermap.org/data/2.5/weather?q=tilichiki,ru&units=imperial) has been processed
# 1507390 : dikson, ru, (https://api.openweathermap.org/data/2.5/weather?q=dikson,ru&units=imperial) has been processed
# 3389822 : salinopolis, br, (https://api.openweathermap.org/data/2.5/weather?q=salinopolis,br&units=imperial) has been processed
# 1735634 : kuching, my, (https://api.openweathermap.org/data/2.5/weather?q=kuching,my&units=imperial) has been processed
# 2630299 : hofn, is, (https://api.openweathermap.org/data/2.5/weather?q=hofn,is&units=imperial) has been processed
# city not found : gat, ly was skipped.
# city not found : amderma, ru was skipped.
# 6185377 : yellowknife, ca, (https://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&units=imperial) has been processed
# 1106643 : quatre cocos, mu, (https://api.openweathermap.org/data/2.5/weather?q=quatre cocos,mu&units=imperial) has been processed
# city not found : saint-georges, gf was skipped.
# 3374336 : porto novo, cv, (https://api.openweathermap.org/data/2.5/weather?q=porto novo,cv&units=imperial) has been processed
# 5024237 : callaway, us, (https://api.openweathermap.org/data/2.5/weather?q=callaway,us&units=imperial) has been processed
# 1262067 : nalgonda, in, (https://api.openweathermap.org/data/2.5/weather?q=nalgonda,in&units=imperial) has been processed
# 996930 : hendrina, za, (https://api.openweathermap.org/data/2.5/weather?q=hendrina,za&units=imperial) has been processed
# 4155996 : fort myers beach, us, (https://api.openweathermap.org/data/2.5/weather?q=fort myers beach,us&units=imperial) has been processed
# city not found : khormuj, ir was skipped.
# 3543299 : puerto padre, cu, (https://api.openweathermap.org/data/2.5/weather?q=puerto padre,cu&units=imperial) has been processed
# city not found : azimur, ma was skipped.
# 1252930 : waris aliganj, in, (https://api.openweathermap.org/data/2.5/weather?q=waris aliganj,in&units=imperial) has been processed
# city not found : belushya guba, ru was skipped.
# 933995 : souillac, mu, (https://api.openweathermap.org/data/2.5/weather?q=souillac,mu&units=imperial) has been processed
# 5847411 : kahului, us, (https://api.openweathermap.org/data/2.5/weather?q=kahului,us&units=imperial) has been processed
# 1610652 : huai thalaeng, th, (https://api.openweathermap.org/data/2.5/weather?q=huai thalaeng,th&units=imperial) has been processed
# 2063036 : port lincoln, au, (https://api.openweathermap.org/data/2.5/weather?q=port lincoln,au&units=imperial) has been processed
# city not found : dolbeau, ca was skipped.
# 1267390 : kavaratti, in, (https://api.openweathermap.org/data/2.5/weather?q=kavaratti,in&units=imperial) has been processed
# 3832899 : viedma, ar, (https://api.openweathermap.org/data/2.5/weather?q=viedma,ar&units=imperial) has been processed
# 286245 : sur, om, (https://api.openweathermap.org/data/2.5/weather?q=sur,om&units=imperial) has been processed
# 7626370 : bud, no, (https://api.openweathermap.org/data/2.5/weather?q=bud,no&units=imperial) has been processed
# 3573061 : saint george, bm, (https://api.openweathermap.org/data/2.5/weather?q=saint george,bm&units=imperial) has been processed
# 898947 : senanga, zm, (https://api.openweathermap.org/data/2.5/weather?q=senanga,zm&units=imperial) has been processed
# 2022773 : khandyga, ru, (https://api.openweathermap.org/data/2.5/weather?q=khandyga,ru&units=imperial) has been processed
# 5671996 : polson, us, (https://api.openweathermap.org/data/2.5/weather?q=polson,us&units=imperial) has been processed
# 1651531 : ambon, id, (https://api.openweathermap.org/data/2.5/weather?q=ambon,id&units=imperial) has been processed
# 3652567 : san cristobal, ec, (https://api.openweathermap.org/data/2.5/weather?q=san cristobal,ec&units=imperial) has been processed
# 5882953 : aklavik, ca, (https://api.openweathermap.org/data/2.5/weather?q=aklavik,ca&units=imperial) has been processed
# 2090495 : morehead, pg, (https://api.openweathermap.org/data/2.5/weather?q=morehead,pg&units=imperial) has been processed
# 866055 : priladozhskiy, ru, (https://api.openweathermap.org/data/2.5/weather?q=priladozhskiy,ru&units=imperial) has been processed
# 3398428 : humberto de campos, br, (https://api.openweathermap.org/data/2.5/weather?q=humberto de campos,br&units=imperial) has been processed
# 1215502 : banda aceh, id, (https://api.openweathermap.org/data/2.5/weather?q=banda aceh,id&units=imperial) has been processed
# 2122090 : pevek, ru, (https://api.openweathermap.org/data/2.5/weather?q=pevek,ru&units=imperial) has been processed
# 3441894 : maldonado, uy, (https://api.openweathermap.org/data/2.5/weather?q=maldonado,uy&units=imperial) has been processed
# 3418910 : upernavik, gl, (https://api.openweathermap.org/data/2.5/weather?q=upernavik,gl&units=imperial) has been processed
# 1024696 : dondo, mz, (https://api.openweathermap.org/data/2.5/weather?q=dondo,mz&units=imperial) has been processed
# 3114531 : palencia, es, (https://api.openweathermap.org/data/2.5/weather?q=palencia,es&units=imperial) has been processed
# 2657267 : anstruther, gb, (https://api.openweathermap.org/data/2.5/weather?q=anstruther,gb&units=imperial) has been processed
# 124291 : mehran, ir, (https://api.openweathermap.org/data/2.5/weather?q=mehran,ir&units=imperial) has been processed
# city not found : artyk, ru was skipped.
# 2156643 : mount gambier, au, (https://api.openweathermap.org/data/2.5/weather?q=mount gambier,au&units=imperial) has been processed
# 2017705 : poyarkovo, ru, (https://api.openweathermap.org/data/2.5/weather?q=poyarkovo,ru&units=imperial) has been processed
# 1337619 : ugoofaaru, mv, (https://api.openweathermap.org/data/2.5/weather?q=ugoofaaru,mv&units=imperial) has been processed
# city not found : galgani, sd was skipped.
# city not found : labutta, mm was skipped.
# 933117 : makaleng, bw, (https://api.openweathermap.org/data/2.5/weather?q=makaleng,bw&units=imperial) has been processed
# 878367 : kitama, tz, (https://api.openweathermap.org/data/2.5/weather?q=kitama,tz&units=imperial) has been processed
# 3985710 : cabo san lucas, mx, (https://api.openweathermap.org/data/2.5/weather?q=cabo san lucas,mx&units=imperial) has been processed
# 3146487 : raudeberg, no, (https://api.openweathermap.org/data/2.5/weather?q=raudeberg,no&units=imperial) has been processed
# 934479 : grand gaube, mu, (https://api.openweathermap.org/data/2.5/weather?q=grand gaube,mu&units=imperial) has been processed
# 1855540 : naze, jp, (https://api.openweathermap.org/data/2.5/weather?q=naze,jp&units=imperial) has been processed
# 1153035 : kathu, th, (https://api.openweathermap.org/data/2.5/weather?q=kathu,th&units=imperial) has been processed
# 5856516 : ahuimanu, us, (https://api.openweathermap.org/data/2.5/weather?q=ahuimanu,us&units=imperial) has been processed
# city not found : burica, pa was skipped.
# 2075720 : broome, au, (https://api.openweathermap.org/data/2.5/weather?q=broome,au&units=imperial) has been processed
# 1229989 : point pedro, lk, (https://api.openweathermap.org/data/2.5/weather?q=point pedro,lk&units=imperial) has been processed
# 5975004 : high level, ca, (https://api.openweathermap.org/data/2.5/weather?q=high level,ca&units=imperial) has been processed
# city not found : attawapiskat, ca was skipped.
# city not found : abu samrah, qa was skipped.
# 877747 : mtwara, tz, (https://api.openweathermap.org/data/2.5/weather?q=mtwara,tz&units=imperial) has been processed
# 5354943 : half moon bay, us, (https://api.openweathermap.org/data/2.5/weather?q=half moon bay,us&units=imperial) has been processed
# 2012530 : zhigansk, ru, (https://api.openweathermap.org/data/2.5/weather?q=zhigansk,ru&units=imperial) has been processed
# 2964782 : dingle, ie, (https://api.openweathermap.org/data/2.5/weather?q=dingle,ie&units=imperial) has been processed
# 2121385 : severo-kurilsk, ru, (https://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk,ru&units=imperial) has been processed
# 475206 : verkhniy avzyan, ru, (https://api.openweathermap.org/data/2.5/weather?q=verkhniy avzyan,ru&units=imperial) has been processed
# 3430443 : necochea, ar, (https://api.openweathermap.org/data/2.5/weather?q=necochea,ar&units=imperial) has been processed
# city not found : louisbourg, ca was skipped.
# 2541479 : nador, ma, (https://api.openweathermap.org/data/2.5/weather?q=nador,ma&units=imperial) has been processed
# 935221 : saint-paul, re, (https://api.openweathermap.org/data/2.5/weather?q=saint-paul,re&units=imperial) has been processed
# 1518542 : karabulak, kz, (https://api.openweathermap.org/data/2.5/weather?q=karabulak,kz&units=imperial) has been processed
# 333750 : jinka, et, (https://api.openweathermap.org/data/2.5/weather?q=jinka,et&units=imperial) has been processed
# 548391 : kirovsk, ru, (https://api.openweathermap.org/data/2.5/weather?q=kirovsk,ru&units=imperial) has been processed
# 2417988 : macenta, gn, (https://api.openweathermap.org/data/2.5/weather?q=macenta,gn&units=imperial) has been processed
# city not found : tapaua, br was skipped.
# city not found : buariki, ki was skipped.
# 2021644 : kraskino, ru, (https://api.openweathermap.org/data/2.5/weather?q=kraskino,ru&units=imperial) has been processed
# 2194098 : ahipara, nz, (https://api.openweathermap.org/data/2.5/weather?q=ahipara,nz&units=imperial) has been processed
# 1529484 : hami, cn, (https://api.openweathermap.org/data/2.5/weather?q=hami,cn&units=imperial) has been processed
# 6144312 : sept-iles, ca, (https://api.openweathermap.org/data/2.5/weather?q=sept-iles,ca&units=imperial) has been processed
# 986717 : kruisfontein, za, (https://api.openweathermap.org/data/2.5/weather?q=kruisfontein,za&units=imperial) has been processed
# city not found : panjwin, iq was skipped.
# 5959335 : gander, ca, (https://api.openweathermap.org/data/2.5/weather?q=gander,ca&units=imperial) has been processed
# 4031574 : provideniya, ru, (https://api.openweathermap.org/data/2.5/weather?q=provideniya,ru&units=imperial) has been processed
# 546105 : nikolskoye, ru, (https://api.openweathermap.org/data/2.5/weather?q=nikolskoye,ru&units=imperial) has been processed
# city not found : yanchukan, ru was skipped.
# 5866063 : kenai, us, (https://api.openweathermap.org/data/2.5/weather?q=kenai,us&units=imperial) has been processed
# city not found : payo, ph was skipped.
# 2361845 : bousse, bf, (https://api.openweathermap.org/data/2.5/weather?q=bousse,bf&units=imperial) has been processed
# 580182 : aykino, ru, (https://api.openweathermap.org/data/2.5/weather?q=aykino,ru&units=imperial) has been processed
# 2145554 : ulladulla, au, (https://api.openweathermap.org/data/2.5/weather?q=ulladulla,au&units=imperial) has been processed
# 3374210 : sao filipe, cv, (https://api.openweathermap.org/data/2.5/weather?q=sao filipe,cv&units=imperial) has been processed
# 2126710 : beringovskiy, ru, (https://api.openweathermap.org/data/2.5/weather?q=beringovskiy,ru&units=imperial) has been processed
# 3386213 : touros, br, (https://api.openweathermap.org/data/2.5/weather?q=touros,br&units=imperial) has been processed
# city not found : tsihombe, mg was skipped.
# 933109 : sehithwa, bw, (https://api.openweathermap.org/data/2.5/weather?q=sehithwa,bw&units=imperial) has been processed
# 6255012 : flinders, au, (https://api.openweathermap.org/data/2.5/weather?q=flinders,au&units=imperial) has been processed
# 3939168 : huarmey, pe, (https://api.openweathermap.org/data/2.5/weather?q=huarmey,pe&units=imperial) has been processed
# 5871146 : palmer, us, (https://api.openweathermap.org/data/2.5/weather?q=palmer,us&units=imperial) has been processed
# 2636638 : stromness, gb, (https://api.openweathermap.org/data/2.5/weather?q=stromness,gb&units=imperial) has been processed
# 3531673 : cancun, mx, (https://api.openweathermap.org/data/2.5/weather?q=cancun,mx&units=imperial) has been processed
# 2181625 : te anau, nz, (https://api.openweathermap.org/data/2.5/weather?q=te anau,nz&units=imperial) has been processed
# 2191562 : dunedin, nz, (https://api.openweathermap.org/data/2.5/weather?q=dunedin,nz&units=imperial) has been processed
# 2518949 : cullera, es, (https://api.openweathermap.org/data/2.5/weather?q=cullera,es&units=imperial) has been processed
# 3420846 : qaqortoq, gl, (https://api.openweathermap.org/data/2.5/weather?q=qaqortoq,gl&units=imperial) has been processed
# 1160571 : khash, ir, (https://api.openweathermap.org/data/2.5/weather?q=khash,ir&units=imperial) has been processed
# 2027042 : batagay-alyta, ru, (https://api.openweathermap.org/data/2.5/weather?q=batagay-alyta,ru&units=imperial) has been processed
# 2976258 : sanary-sur-mer, fr, (https://api.openweathermap.org/data/2.5/weather?q=sanary-sur-mer,fr&units=imperial) has been processed
# 5367788 : lompoc, us, (https://api.openweathermap.org/data/2.5/weather?q=lompoc,us&units=imperial) has been processed
# 5554428 : ketchikan, us, (https://api.openweathermap.org/data/2.5/weather?q=ketchikan,us&units=imperial) has been processed
# 2450173 : taoudenni, ml, (https://api.openweathermap.org/data/2.5/weather?q=taoudenni,ml&units=imperial) has been processed
# 3932145 : pisco, pe, (https://api.openweathermap.org/data/2.5/weather?q=pisco,pe&units=imperial) has been processed
# 3896218 : castro, cl, (https://api.openweathermap.org/data/2.5/weather?q=castro,cl&units=imperial) has been processed
# city not found : skagastrond, is was skipped.
# city not found : gurgan, az was skipped.
# 553725 : kamenka, ru, (https://api.openweathermap.org/data/2.5/weather?q=kamenka,ru&units=imperial) has been processed
# 4032243 : vaini, to, (https://api.openweathermap.org/data/2.5/weather?q=vaini,to&units=imperial) has been processed
# 237478 : mobaye, cf, (https://api.openweathermap.org/data/2.5/weather?q=mobaye,cf&units=imperial) has been processed
# 1865309 : katsuura, jp, (https://api.openweathermap.org/data/2.5/weather?q=katsuura,jp&units=imperial) has been processed
# 3533462 : acapulco, mx, (https://api.openweathermap.org/data/2.5/weather?q=acapulco,mx&units=imperial) has been processed
# 2444995 : filingue, ne, (https://api.openweathermap.org/data/2.5/weather?q=filingue,ne&units=imperial) has been processed
# 605155 : kiruna, se, (https://api.openweathermap.org/data/2.5/weather?q=kiruna,se&units=imperial) has been processed
# 3427537 : veinticinco de mayo, ar, (https://api.openweathermap.org/data/2.5/weather?q=veinticinco de mayo,ar&units=imperial) has been processed
# 2173911 : broken hill, au, (https://api.openweathermap.org/data/2.5/weather?q=broken hill,au&units=imperial) has been processed
# 2447513 : arlit, ne, (https://api.openweathermap.org/data/2.5/weather?q=arlit,ne&units=imperial) has been processed
# 2707684 : harnosand, se, (https://api.openweathermap.org/data/2.5/weather?q=harnosand,se&units=imperial) has been processed
# 6113365 : prince george, ca, (https://api.openweathermap.org/data/2.5/weather?q=prince george,ca&units=imperial) has been processed
# 5969025 : haines junction, ca, (https://api.openweathermap.org/data/2.5/weather?q=haines junction,ca&units=imperial) has been processed
# 6089245 : norman wells, ca, (https://api.openweathermap.org/data/2.5/weather?q=norman wells,ca&units=imperial) has been processed
# 2334008 : kontagora, ng, (https://api.openweathermap.org/data/2.5/weather?q=kontagora,ng&units=imperial) has been processed
# 2516925 : guadix, es, (https://api.openweathermap.org/data/2.5/weather?q=guadix,es&units=imperial) has been processed
# 3661894 : tonantins, br, (https://api.openweathermap.org/data/2.5/weather?q=tonantins,br&units=imperial) has been processed
# 4036284 : alofi, nu, (https://api.openweathermap.org/data/2.5/weather?q=alofi,nu&units=imperial) has been processed
# 5692947 : williston, us, (https://api.openweathermap.org/data/2.5/weather?q=williston,us&units=imperial) has been processed
# 5380437 : pacific grove, us, (https://api.openweathermap.org/data/2.5/weather?q=pacific grove,us&units=imperial) has been processed
# 2629833 : husavik, is, (https://api.openweathermap.org/data/2.5/weather?q=husavik,is&units=imperial) has been processed
# 3853354 : junin, ar, (https://api.openweathermap.org/data/2.5/weather?q=junin,ar&units=imperial) has been processed
# 5563397 : eureka, us, (https://api.openweathermap.org/data/2.5/weather?q=eureka,us&units=imperial) has been processed
# 5924351 : clyde river, ca, (https://api.openweathermap.org/data/2.5/weather?q=clyde river,ca&units=imperial) has been processed
# 1737714 : limbang, my, (https://api.openweathermap.org/data/2.5/weather?q=limbang,my&units=imperial) has been processed
# 3421193 : paamiut, gl, (https://api.openweathermap.org/data/2.5/weather?q=paamiut,gl&units=imperial) has been processed
# city not found : faya, td was skipped.
# city not found : bobo dioulasso, bf was skipped.
# 607610 : zhanaozen, kz, (https://api.openweathermap.org/data/2.5/weather?q=zhanaozen,kz&units=imperial) has been processed
# 3693584 : pimentel, pe, (https://api.openweathermap.org/data/2.5/weather?q=pimentel,pe&units=imperial) has been processed
# 3700393 : tubuala, pa, (https://api.openweathermap.org/data/2.5/weather?q=tubuala,pa&units=imperial) has been processed
# 1497210 : novoagansk, ru, (https://api.openweathermap.org/data/2.5/weather?q=novoagansk,ru&units=imperial) has been processed
# 5826027 : gillette, us, (https://api.openweathermap.org/data/2.5/weather?q=gillette,us&units=imperial) has been processed
# 359783 : asyut, eg, (https://api.openweathermap.org/data/2.5/weather?q=asyut,eg&units=imperial) has been processed
# 1795632 : shenjiamen, cn, (https://api.openweathermap.org/data/2.5/weather?q=shenjiamen,cn&units=imperial) has been processed
# city not found : krasnoselkup, ru was skipped.
# 777019 : vardo, no, (https://api.openweathermap.org/data/2.5/weather?q=vardo,no&units=imperial) has been processed
# 1487332 : verkhnyaya inta, ru, (https://api.openweathermap.org/data/2.5/weather?q=verkhnyaya inta,ru&units=imperial) has been processed
# 761546 : poniatowa, pl, (https://api.openweathermap.org/data/2.5/weather?q=poniatowa,pl&units=imperial) has been processed
# 6111632 : port alberni, ca, (https://api.openweathermap.org/data/2.5/weather?q=port alberni,ca&units=imperial) has been processed
# city not found : barentsburg, sj was skipped.
# city not found : umm durman, sd was skipped.
# 719396 : karcsa, hu, (https://api.openweathermap.org/data/2.5/weather?q=karcsa,hu&units=imperial) has been processed
# 3361934 : saldanha, za, (https://api.openweathermap.org/data/2.5/weather?q=saldanha,za&units=imperial) has been processed
# 2084442 : vanimo, pg, (https://api.openweathermap.org/data/2.5/weather?q=vanimo,pg&units=imperial) has been processed
# 534245 : lopandino, ru, (https://api.openweathermap.org/data/2.5/weather?q=lopandino,ru&units=imperial) has been processed
# 3359638 : walvis bay, na, (https://api.openweathermap.org/data/2.5/weather?q=walvis bay,na&units=imperial) has been processed
# 3412093 : vestmannaeyjar, is, (https://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar,is&units=imperial) has been processed
# city not found : linshu, cn was skipped.
# 3466980 : caravelas, br, (https://api.openweathermap.org/data/2.5/weather?q=caravelas,br&units=imperial) has been processed
# 2034400 : tongliao, cn, (https://api.openweathermap.org/data/2.5/weather?q=tongliao,cn&units=imperial) has been processed
# 2460954 : araouane, ml, (https://api.openweathermap.org/data/2.5/weather?q=araouane,ml&units=imperial) has been processed
# 1242110 : kalmunai, lk, (https://api.openweathermap.org/data/2.5/weather?q=kalmunai,lk&units=imperial) has been processed
# 934322 : mahebourg, mu, (https://api.openweathermap.org/data/2.5/weather?q=mahebourg,mu&units=imperial) has been processed
# 3471451 : arraial do cabo, br, (https://api.openweathermap.org/data/2.5/weather?q=arraial do cabo,br&units=imperial) has been processed
# city not found : karaul, ru was skipped.
# 1268814 : joshimath, in, (https://api.openweathermap.org/data/2.5/weather?q=joshimath,in&units=imperial) has been processed
# 3416888 : grindavik, is, (https://api.openweathermap.org/data/2.5/weather?q=grindavik,is&units=imperial) has been processed
# 2013465 : verkhoyansk, ru, (https://api.openweathermap.org/data/2.5/weather?q=verkhoyansk,ru&units=imperial) has been processed
# 4021858 : guerrero negro, mx, (https://api.openweathermap.org/data/2.5/weather?q=guerrero negro,mx&units=imperial) has been processed
# 1528735 : batken, kg, (https://api.openweathermap.org/data/2.5/weather?q=batken,kg&units=imperial) has been processed
# 3489657 : lucea, jm, (https://api.openweathermap.org/data/2.5/weather?q=lucea,jm&units=imperial) has been processed
# 53654 : mogadishu, so, (https://api.openweathermap.org/data/2.5/weather?q=mogadishu,so&units=imperial) has been processed
# city not found : nguiu, au was skipped.
# 779554 : honningsvag, no, (https://api.openweathermap.org/data/2.5/weather?q=honningsvag,no&units=imperial) has been processed
# 4886374 : cambridge, us, (https://api.openweathermap.org/data/2.5/weather?q=cambridge,us&units=imperial) has been processed
# 2152668 : portland, au, (https://api.openweathermap.org/data/2.5/weather?q=portland,au&units=imperial) has been processed
# 2137773 : vao, nc, (https://api.openweathermap.org/data/2.5/weather?q=vao,nc&units=imperial) has been processed
# 2415703 : siguiri, gn, (https://api.openweathermap.org/data/2.5/weather?q=siguiri,gn&units=imperial) has been processed
# 2158767 : mareeba, au, (https://api.openweathermap.org/data/2.5/weather?q=mareeba,au&units=imperial) has been processed
# 1161724 : chabahar, ir, (https://api.openweathermap.org/data/2.5/weather?q=chabahar,ir&units=imperial) has been processed
# 4031742 : egvekinot, ru, (https://api.openweathermap.org/data/2.5/weather?q=egvekinot,ru&units=imperial) has been processed
# 2301217 : ejura, gh, (https://api.openweathermap.org/data/2.5/weather?q=ejura,gh&units=imperial) has been processed
# 1503037 : kodinsk, ru, (https://api.openweathermap.org/data/2.5/weather?q=kodinsk,ru&units=imperial) has been processed
# city not found : paradwip, in was skipped.
# 2014833 : tura, ru, (https://api.openweathermap.org/data/2.5/weather?q=tura,ru&units=imperial) has been processed
# 6355222 : yulara, au, (https://api.openweathermap.org/data/2.5/weather?q=yulara,au&units=imperial) has been processed
# 3133895 : tromso, no, (https://api.openweathermap.org/data/2.5/weather?q=tromso,no&units=imperial) has been processed
# 1625908 : sungairaya, id, (https://api.openweathermap.org/data/2.5/weather?q=sungairaya,id&units=imperial) has been processed
# 4207783 : marietta, us, (https://api.openweathermap.org/data/2.5/weather?q=marietta,us&units=imperial) has been processed
# 2052479 : zhuhai, cn, (https://api.openweathermap.org/data/2.5/weather?q=zhuhai,cn&units=imperial) has been processed
# 468776 : yashalta, ru, (https://api.openweathermap.org/data/2.5/weather?q=yashalta,ru&units=imperial) has been processed
# 1636426 : manggar, id, (https://api.openweathermap.org/data/2.5/weather?q=manggar,id&units=imperial) has been processed
# city not found : mutsamudu, km was skipped.
# 1280849 : kashi, cn, (https://api.openweathermap.org/data/2.5/weather?q=kashi,cn&units=imperial) has been processed
# 2381334 : atar, mr, (https://api.openweathermap.org/data/2.5/weather?q=atar,mr&units=imperial) has been processed
# city not found : yefira, gr was skipped.
# city not found : camana, pe was skipped.
# 964712 : plettenberg bay, za, (https://api.openweathermap.org/data/2.5/weather?q=plettenberg bay,za&units=imperial) has been processed
# 1062663 : mahajanga, mg, (https://api.openweathermap.org/data/2.5/weather?q=mahajanga,mg&units=imperial) has been processed
# 3868626 : valparaiso, cl, (https://api.openweathermap.org/data/2.5/weather?q=valparaiso,cl&units=imperial) has been processed
# city not found : bereda, so was skipped.
# 3533389 : actopan, mx, (https://api.openweathermap.org/data/2.5/weather?q=actopan,mx&units=imperial) has been processed
# 88533 : awjilah, ly, (https://api.openweathermap.org/data/2.5/weather?q=awjilah,ly&units=imperial) has been processed
# 1516048 : hovd, mn, (https://api.openweathermap.org/data/2.5/weather?q=hovd,mn&units=imperial) has been processed
# 1799869 : nanning, cn, (https://api.openweathermap.org/data/2.5/weather?q=nanning,cn&units=imperial) has been processed
# 2318123 : yenagoa, ng, (https://api.openweathermap.org/data/2.5/weather?q=yenagoa,ng&units=imperial) has been processed
# 1640344 : kendari, id, (https://api.openweathermap.org/data/2.5/weather?q=kendari,id&units=imperial) has been processed
# 6160919 : taber, ca, (https://api.openweathermap.org/data/2.5/weather?q=taber,ca&units=imperial) has been processed
# city not found : bengkulu, id was skipped.
# 69559 : zabid, ye, (https://api.openweathermap.org/data/2.5/weather?q=zabid,ye&units=imperial) has been processed
# city not found : urumqi, cn was skipped.
# 2122104 : petropavlovsk-kamchatskiy, ru, (https://api.openweathermap.org/data/2.5/weather?q=petropavlovsk-kamchatskiy,ru&units=imperial) has been processed
# 1213855 : sibolga, id, (https://api.openweathermap.org/data/2.5/weather?q=sibolga,id&units=imperial) has been processed
# 2094342 : kavieng, pg, (https://api.openweathermap.org/data/2.5/weather?q=kavieng,pg&units=imperial) has been processed
# 1500933 : labytnangi, ru, (https://api.openweathermap.org/data/2.5/weather?q=labytnangi,ru&units=imperial) has been processed
# 1263997 : mamallapuram, in, (https://api.openweathermap.org/data/2.5/weather?q=mamallapuram,in&units=imperial) has been processed
# city not found : nizhneyansk, ru was skipped.
# 2360541 : gayeri, bf, (https://api.openweathermap.org/data/2.5/weather?q=gayeri,bf&units=imperial) has been processed
# 1698289 : pundaguitan, ph, (https://api.openweathermap.org/data/2.5/weather?q=pundaguitan,ph&units=imperial) has been processed
# 140380 : bojnurd, ir, (https://api.openweathermap.org/data/2.5/weather?q=bojnurd,ir&units=imperial) has been processed
# 2063056 : port augusta, au, (https://api.openweathermap.org/data/2.5/weather?q=port augusta,au&units=imperial) has been processed
# 1715015 : dicabisagan, ph, (https://api.openweathermap.org/data/2.5/weather?q=dicabisagan,ph&units=imperial) has been processed
# 3421719 : narsaq, gl, (https://api.openweathermap.org/data/2.5/weather?q=narsaq,gl&units=imperial) has been processed
# 236950 : obo, cf, (https://api.openweathermap.org/data/2.5/weather?q=obo,cf&units=imperial) has been processed
# city not found : acarau, br was skipped.
# 1214488 : meulaboh, id, (https://api.openweathermap.org/data/2.5/weather?q=meulaboh,id&units=imperial) has been processed
# 633221 : uusikaupunki, fi, (https://api.openweathermap.org/data/2.5/weather?q=uusikaupunki,fi&units=imperial) has been processed
# 3860443 : comodoro rivadavia, ar, (https://api.openweathermap.org/data/2.5/weather?q=comodoro rivadavia,ar&units=imperial) has been processed
# 2027296 : aykhal, ru, (https://api.openweathermap.org/data/2.5/weather?q=aykhal,ru&units=imperial) has been processed
# 2142316 : yeppoon, au, (https://api.openweathermap.org/data/2.5/weather?q=yeppoon,au&units=imperial) has been processed
# 2172880 : byron bay, au, (https://api.openweathermap.org/data/2.5/weather?q=byron bay,au&units=imperial) has been processed
# city not found : umzimvubu, za was skipped.
# 3931223 : puquio, pe, (https://api.openweathermap.org/data/2.5/weather?q=puquio,pe&units=imperial) has been processed
# 2127060 : arman, ru, (https://api.openweathermap.org/data/2.5/weather?q=arman,ru&units=imperial) has been processed
# 2070998 : geraldton, au, (https://api.openweathermap.org/data/2.5/weather?q=geraldton,au&units=imperial) has been processed
# 5814916 : walla walla, us, (https://api.openweathermap.org/data/2.5/weather?q=walla walla,us&units=imperial) has been processed
# 2377457 : nouadhibou, mr, (https://api.openweathermap.org/data/2.5/weather?q=nouadhibou,mr&units=imperial) has been processed
# 8142546 : lasem, id, (https://api.openweathermap.org/data/2.5/weather?q=lasem,id&units=imperial) has been processed
# 1623502 : sabang, id, (https://api.openweathermap.org/data/2.5/weather?q=sabang,id&units=imperial) has been processed
# 1499053 : megion, ru, (https://api.openweathermap.org/data/2.5/weather?q=megion,ru&units=imperial) has been processed
# city not found : warqla, dz was skipped.
# 2014718 : tynda, ru, (https://api.openweathermap.org/data/2.5/weather?q=tynda,ru&units=imperial) has been processed
# 2025256 : chumikan, ru, (https://api.openweathermap.org/data/2.5/weather?q=chumikan,ru&units=imperial) has been processed
# 4732862 : nome, us, (https://api.openweathermap.org/data/2.5/weather?q=nome,us&units=imperial) has been processed
# city not found : chengmai, cn was skipped.
# 2178753 : kirakira, sb, (https://api.openweathermap.org/data/2.5/weather?q=kirakira,sb&units=imperial) has been processed
# 3190342 : bezdan, rs, (https://api.openweathermap.org/data/2.5/weather?q=bezdan,rs&units=imperial) has been processed
# 3894426 : coihaique, cl, (https://api.openweathermap.org/data/2.5/weather?q=coihaique,cl&units=imperial) has been processed
# city not found : karamay, cn was skipped.
# 167357 : manbij, sy, (https://api.openweathermap.org/data/2.5/weather?q=manbij,sy&units=imperial) has been processed
# 64435 : berbera, so, (https://api.openweathermap.org/data/2.5/weather?q=berbera,so&units=imperial) has been processed
# 3691954 : sechura, pe, (https://api.openweathermap.org/data/2.5/weather?q=sechura,pe&units=imperial) has been processed
# 186827 : meru, ke, (https://api.openweathermap.org/data/2.5/weather?q=meru,ke&units=imperial) has been processed
# city not found : vaitupu, wf was skipped.
# 2189343 : kaeo, nz, (https://api.openweathermap.org/data/2.5/weather?q=kaeo,nz&units=imperial) has been processed
# 1262260 : nagapattinam, in, (https://api.openweathermap.org/data/2.5/weather?q=nagapattinam,in&units=imperial) has been processed
# 1788852 : xining, cn, (https://api.openweathermap.org/data/2.5/weather?q=xining,cn&units=imperial) has been processed
# 3836669 : san rafael, ar, (https://api.openweathermap.org/data/2.5/weather?q=san rafael,ar&units=imperial) has been processed
# 1337610 : thinadhoo, mv, (https://api.openweathermap.org/data/2.5/weather?q=thinadhoo,mv&units=imperial) has been processed
# 1650434 : bambanglipuro, id, (https://api.openweathermap.org/data/2.5/weather?q=bambanglipuro,id&units=imperial) has been processed
# 1258640 : ramnagar, in, (https://api.openweathermap.org/data/2.5/weather?q=ramnagar,in&units=imperial) has been processed
# 2276492 : harper, lr, (https://api.openweathermap.org/data/2.5/weather?q=harper,lr&units=imperial) has been processed
# 3397763 : jacareacanga, br, (https://api.openweathermap.org/data/2.5/weather?q=jacareacanga,br&units=imperial) has been processed
# 2030065 : mandalgovi, mn, (https://api.openweathermap.org/data/2.5/weather?q=mandalgovi,mn&units=imperial) has been processed
# 4191916 : douglas, us, (https://api.openweathermap.org/data/2.5/weather?q=douglas,us&units=imperial) has been processed
# 863061 : usinsk, ru, (https://api.openweathermap.org/data/2.5/weather?q=usinsk,ru&units=imperial) has been processed
# 5972762 : hay river, ca, (https://api.openweathermap.org/data/2.5/weather?q=hay river,ca&units=imperial) has been processed
# 2019718 : mukhen, ru, (https://api.openweathermap.org/data/2.5/weather?q=mukhen,ru&units=imperial) has been processed
# city not found : palabuhanratu, id was skipped.
# 2013865 : ust-uda, ru, (https://api.openweathermap.org/data/2.5/weather?q=ust-uda,ru&units=imperial) has been processed
# 482230 : tonkino, ru, (https://api.openweathermap.org/data/2.5/weather?q=tonkino,ru&units=imperial) has been processed
# 2522325 : aguimes, es, (https://api.openweathermap.org/data/2.5/weather?q=aguimes,es&units=imperial) has been processed
# 3456642 : mozarlandia, br, (https://api.openweathermap.org/data/2.5/weather?q=mozarlandia,br&units=imperial) has been processed
# 707753 : horlivka, ua, (https://api.openweathermap.org/data/2.5/weather?q=horlivka,ua&units=imperial) has been processed
# ...
# 1785036 : zhangye, cn, (https://api.openweathermap.org/data/2.5/weather?q=zhangye,cn&units=imperial) has been processed
# 553152 : krasnogvardeyets, ru, (https://api.openweathermap.org/data/2.5/weather?q=krasnogvardeyets,ru&units=imperial) has been processed
# 2032614 : baruun-urt, mn, (https://api.openweathermap.org/data/2.5/weather?q=baruun-urt,mn&units=imperial) has been processed
# 3870243 : taltal, cl, (https://api.openweathermap.org/data/2.5/weather?q=taltal,cl&units=imperial) has been processed
# 3577154 : oranjestad, aw, (https://api.openweathermap.org/data/2.5/weather?q=oranjestad,aw&units=imperial) has been processed
# 6639619 : saint-raymond, ca, (https://api.openweathermap.org/data/2.5/weather?q=saint-raymond,ca&units=imperial) has been processed
# 915471 : kalabo, zm, (https://api.openweathermap.org/data/2.5/weather?q=kalabo,zm&units=imperial) has been processed
# 648090 : lieksa, fi, (https://api.openweathermap.org/data/2.5/weather?q=lieksa,fi&units=imperial) has been processed
# 479071 : umba, ru, (https://api.openweathermap.org/data/2.5/weather?q=umba,ru&units=imperial) has been processed
# 3901903 : uyuni, bo, (https://api.openweathermap.org/data/2.5/weather?q=uyuni,bo&units=imperial) has been processed
# 1816256 : botou, cn, (https://api.openweathermap.org/data/2.5/weather?q=botou,cn&units=imperial) has been processed
# 4011743 : constitucion, mx, (https://api.openweathermap.org/data/2.5/weather?q=constitucion,mx&units=imperial) has been processed
# 2034221 : dongzhen, cn, (https://api.openweathermap.org/data/2.5/weather?q=dongzhen,cn&units=imperial) has been processed
# 1626493 : srandakan, id, (https://api.openweathermap.org/data/2.5/weather?q=srandakan,id&units=imperial) has been processed
# 2738785 : guarda, pt, (https://api.openweathermap.org/data/2.5/weather?q=guarda,pt&units=imperial) has been processed
# 3474574 : palmas, br, (https://api.openweathermap.org/data/2.5/weather?q=palmas,br&units=imperial) has been processed
# 6690296 : saint-joseph, re, (https://api.openweathermap.org/data/2.5/weather?q=saint-joseph,re&units=imperial) has been processed
# 1185239 : mathbaria, bd, (https://api.openweathermap.org/data/2.5/weather?q=mathbaria,bd&units=imperial) has been processed
# 5992154 : kindersley, ca, (https://api.openweathermap.org/data/2.5/weather?q=kindersley,ca&units=imperial) has been processed
# 1283285 : jumla, np, (https://api.openweathermap.org/data/2.5/weather?q=jumla,np&units=imperial) has been processed
# 2210247 : tripoli, ly, (https://api.openweathermap.org/data/2.5/weather?q=tripoli,ly&units=imperial) has been processed
# 3576663 : laborie, lc, (https://api.openweathermap.org/data/2.5/weather?q=laborie,lc&units=imperial) has been processed
# 1226260 : trincomalee, lk, (https://api.openweathermap.org/data/2.5/weather?q=trincomalee,lk&units=imperial) has been processed
# 962367 : richards bay, za, (https://api.openweathermap.org/data/2.5/weather?q=richards bay,za&units=imperial) has been processed
# 2160517 : launceston, au, (https://api.openweathermap.org/data/2.5/weather?q=launceston,au&units=imperial) has been processed
# 3980627 : valle de allende, mx, (https://api.openweathermap.org/data/2.5/weather?q=valle de allende,mx&units=imperial) has been processed
# 2160735 : lakes entrance, au, (https://api.openweathermap.org/data/2.5/weather?q=lakes entrance,au&units=imperial) has been processed
# 464790 : zapolyarnyy, ru, (https://api.openweathermap.org/data/2.5/weather?q=zapolyarnyy,ru&units=imperial) has been processed
# 315498 : eregli, tr, (https://api.openweathermap.org/data/2.5/weather?q=eregli,tr&units=imperial) has been processed
# 2188874 : russell, nz, (https://api.openweathermap.org/data/2.5/weather?q=russell,nz&units=imperial) has been processed
# city not found : sentyabrskiy, ru was skipped.
# 459201 : jurmala, lv, (https://api.openweathermap.org/data/2.5/weather?q=jurmala,lv&units=imperial) has been processed
# 4017743 : badiraguato, mx, (https://api.openweathermap.org/data/2.5/weather?q=badiraguato,mx&units=imperial) has been processed
# 3692073 : santiago de cao, pe, (https://api.openweathermap.org/data/2.5/weather?q=santiago de cao,pe&units=imperial) has been processed
# 2521857 : almonte, es, (https://api.openweathermap.org/data/2.5/weather?q=almonte,es&units=imperial) has been processed
# 2449893 : tessalit, ml, (https://api.openweathermap.org/data/2.5/weather?q=tessalit,ml&units=imperial) has been processed
# 1861416 : ishigaki, jp, (https://api.openweathermap.org/data/2.5/weather?q=ishigaki,jp&units=imperial) has been processed
# 1848373 : fukue, jp, (https://api.openweathermap.org/data/2.5/weather?q=fukue,jp&units=imperial) has been processed
# 2015217 : tokur, ru, (https://api.openweathermap.org/data/2.5/weather?q=tokur,ru&units=imperial) has been processed
# 1283368 : gulariya, np, (https://api.openweathermap.org/data/2.5/weather?q=gulariya,np&units=imperial) has been processed
# 6538185 : acqui terme, it, (https://api.openweathermap.org/data/2.5/weather?q=acqui terme,it&units=imperial) has been processed
# 3440777 : rocha, uy, (https://api.openweathermap.org/data/2.5/weather?q=rocha,uy&units=imperial) has been processed
# 2065594 : mount isa, au, (https://api.openweathermap.org/data/2.5/weather?q=mount isa,au&units=imperial) has been processed
# 690985 : turbiv, ua, (https://api.openweathermap.org/data/2.5/weather?q=turbiv,ua&units=imperial) has been processed
# 3662927 : santa vitoria, br, (https://api.openweathermap.org/data/2.5/weather?q=santa vitoria,br&units=imperial) has been processed
# 1848976 : wajima, jp, (https://api.openweathermap.org/data/2.5/weather?q=wajima,jp&units=imperial) has been processed
# 2015852 : svetlaya, ru, (https://api.openweathermap.org/data/2.5/weather?q=svetlaya,ru&units=imperial) has been processed
# 3372472 : vila franca do campo, pt, (https://api.openweathermap.org/data/2.5/weather?q=vila franca do campo,pt&units=imperial) has been processed
# 933644 : ghanzi, bw, (https://api.openweathermap.org/data/2.5/weather?q=ghanzi,bw&units=imperial) has been processed
# 1486910 : komsomolskiy, ru, (https://api.openweathermap.org/data/2.5/weather?q=komsomolskiy,ru&units=imperial) has been processed
# 241131 : victoria, sc, (https://api.openweathermap.org/data/2.5/weather?q=victoria,sc&units=imperial) has been processed
# 4761171 : gloucester, us, (https://api.openweathermap.org/data/2.5/weather?q=gloucester,us&units=imperial) has been processed
# 5710360 : winnemucca, us, (https://api.openweathermap.org/data/2.5/weather?q=winnemucca,us&units=imperial) has been processed
# 3994469 : ojinaga, mx, (https://api.openweathermap.org/data/2.5/weather?q=ojinaga,mx&units=imperial) has been processed
# 6113463 : princeton, ca, (https://api.openweathermap.org/data/2.5/weather?q=princeton,ca&units=imperial) has been processed
# 2151187 : roma, au, (https://api.openweathermap.org/data/2.5/weather?q=roma,au&units=imperial) has been processed
# 3461370 : imbituba, br, (https://api.openweathermap.org/data/2.5/weather?q=imbituba,br&units=imperial) has been processed
# 4000821 : acuitzio, mx, (https://api.openweathermap.org/data/2.5/weather?q=acuitzio,mx&units=imperial) has been processed
# 2396853 : omboue, ga, (https://api.openweathermap.org/data/2.5/weather?q=omboue,ga&units=imperial) has been processed
# 2446796 : bilma, ne, (https://api.openweathermap.org/data/2.5/weather?q=bilma,ne&units=imperial) has been processed
# 1699205 : morong, ph, (https://api.openweathermap.org/data/2.5/weather?q=morong,ph&units=imperial) has been processed
# 3899695 : ancud, cl, (https://api.openweathermap.org/data/2.5/weather?q=ancud,cl&units=imperial) has been processed
# 292223 : dubai, ae, (https://api.openweathermap.org/data/2.5/weather?q=dubai,ae&units=imperial) has been processed
# 133595 : gerash, ir, (https://api.openweathermap.org/data/2.5/weather?q=gerash,ir&units=imperial) has been processed
# city not found : shibarghan, af was skipped.
# 258175 : lixourion, gr, (https://api.openweathermap.org/data/2.5/weather?q=lixourion,gr&units=imperial) has been processed
# 978895 : margate, za, (https://api.openweathermap.org/data/2.5/weather?q=margate,za&units=imperial) has been processed
# 5442007 : trinidad, us, (https://api.openweathermap.org/data/2.5/weather?q=trinidad,us&units=imperial) has been processed
# 2012532 : zhigalovo, ru, (https://api.openweathermap.org/data/2.5/weather?q=zhigalovo,ru&units=imperial) has been processed
# city not found : nioro, ml was skipped.
# 3451138 : rio grande, br, (https://api.openweathermap.org/data/2.5/weather?q=rio grande,br&units=imperial) has been processed
# 2020838 : lensk, ru, (https://api.openweathermap.org/data/2.5/weather?q=lensk,ru&units=imperial) has been processed
# 1703471 : maitum, ph, (https://api.openweathermap.org/data/2.5/weather?q=maitum,ph&units=imperial) has been processed
# 113659 : tabas, ir, (https://api.openweathermap.org/data/2.5/weather?q=tabas,ir&units=imperial) has been processed
# 2109528 : buala, sb, (https://api.openweathermap.org/data/2.5/weather?q=buala,sb&units=imperial) has been processed
# 3869716 : tocopilla, cl, (https://api.openweathermap.org/data/2.5/weather?q=tocopilla,cl&units=imperial) has been processed
# 3899539 : antofagasta, cl, (https://api.openweathermap.org/data/2.5/weather?q=antofagasta,cl&units=imperial) has been processed
# city not found : bolungarvik, is was skipped.
# 1511846 : oktyabrskoye, ru, (https://api.openweathermap.org/data/2.5/weather?q=oktyabrskoye,ru&units=imperial) has been processed
# 6067747 : matagami, ca, (https://api.openweathermap.org/data/2.5/weather?q=matagami,ca&units=imperial) has been processed
# 5710035 : west wendover, us, (https://api.openweathermap.org/data/2.5/weather?q=west wendover,us&units=imperial) has been processed
# 2014927 : tulun, ru, (https://api.openweathermap.org/data/2.5/weather?q=tulun,ru&units=imperial) has been processed
# 2281951 : sassandra, ci, (https://api.openweathermap.org/data/2.5/weather?q=sassandra,ci&units=imperial) has been processed
# 1151074 : prachuap khiri khan, th, (https://api.openweathermap.org/data/2.5/weather?q=prachuap khiri khan,th&units=imperial) has been processed
# 364027 : wagar, sd, (https://api.openweathermap.org/data/2.5/weather?q=wagar,sd&units=imperial) has been processed
# 1154689 : ko samui, th, (https://api.openweathermap.org/data/2.5/weather?q=ko samui,th&units=imperial) has been processed
# 3936456 : lima, pe, (https://api.openweathermap.org/data/2.5/weather?q=lima,pe&units=imperial) has been processed
# 2127202 : anadyr, ru, (https://api.openweathermap.org/data/2.5/weather?q=anadyr,ru&units=imperial) has been processed
# city not found : teul, mx was skipped.
# 922806 : kipushi, cd, (https://api.openweathermap.org/data/2.5/weather?q=kipushi,cd&units=imperial) has been processed
# 1484892 : zyryanskoye, ru, (https://api.openweathermap.org/data/2.5/weather?q=zyryanskoye,ru&units=imperial) has been processed
# 1738050 : miri, my, (https://api.openweathermap.org/data/2.5/weather?q=miri,my&units=imperial) has been processed
# city not found : kismayo, so was skipped.
# city not found : ketchenery, ru was skipped.
# 2119283 : zyryanka, ru, (https://api.openweathermap.org/data/2.5/weather?q=zyryanka,ru&units=imperial) has been processed
# 2377450 : nouakchott, mr, (https://api.openweathermap.org/data/2.5/weather?q=nouakchott,mr&units=imperial) has been processed
# 1526273 : astana, kz, (https://api.openweathermap.org/data/2.5/weather?q=astana,kz&units=imperial) has been processed
# 2449067 : tombouctou, ml, (https://api.openweathermap.org/data/2.5/weather?q=tombouctou,ml&units=imperial) has been processed
# 685021 : berevoesti, ro, (https://api.openweathermap.org/data/2.5/weather?q=berevoesti,ro&units=imperial) has been processed
# 2212775 : sabha, ly, (https://api.openweathermap.org/data/2.5/weather?q=sabha,ly&units=imperial) has been processed
# 525426 : sobolevo, ru, (https://api.openweathermap.org/data/2.5/weather?q=sobolevo,ru&units=imperial) has been processed
# 1798480 : pumiao, cn, (https://api.openweathermap.org/data/2.5/weather?q=pumiao,cn&units=imperial) has been processed
# city not found : asau, tv was skipped.
# 1643920 : jatiroto, id, (https://api.openweathermap.org/data/2.5/weather?q=jatiroto,id&units=imperial) has been processed
# 3994911 : nocupetaro, mx, (https://api.openweathermap.org/data/2.5/weather?q=nocupetaro,mx&units=imperial) has been processed
# 1715431 : talisayan, ph, (https://api.openweathermap.org/data/2.5/weather?q=talisayan,ph&units=imperial) has been processed
# 2140558 : koumac, nc, (https://api.openweathermap.org/data/2.5/weather?q=koumac,nc&units=imperial) has been processed
# 1486321 : yar-sale, ru, (https://api.openweathermap.org/data/2.5/weather?q=yar-sale,ru&units=imperial) has been processed
# 4798308 : beckley, us, (https://api.openweathermap.org/data/2.5/weather?q=beckley,us&units=imperial) has been processed
# 566629 : demyansk, ru, (https://api.openweathermap.org/data/2.5/weather?q=demyansk,ru&units=imperial) has been processed
# 3981460 : coahuayana, mx, (https://api.openweathermap.org/data/2.5/weather?q=coahuayana,mx&units=imperial) has been processed
# 211647 : lodja, cd, (https://api.openweathermap.org/data/2.5/weather?q=lodja,cd&units=imperial) has been processed
# 3347019 : namibe, ao, (https://api.openweathermap.org/data/2.5/weather?q=namibe,ao&units=imperial) has been processed
# 535839 : leshukonskoye, ru, (https://api.openweathermap.org/data/2.5/weather?q=leshukonskoye,ru&units=imperial) has been processed
# 2258984 : kinkala, cg, (https://api.openweathermap.org/data/2.5/weather?q=kinkala,cg&units=imperial) has been processed
# 2754817 : harlingen, nl, (https://api.openweathermap.org/data/2.5/weather?q=harlingen,nl&units=imperial) has been processed
# 1269557 : masaurhi, in, (https://api.openweathermap.org/data/2.5/weather?q=masaurhi,in&units=imperial) has been processed
# 2525769 : adrano, it, (https://api.openweathermap.org/data/2.5/weather?q=adrano,it&units=imperial) has been processed
# 3938415 : ilo, pe, (https://api.openweathermap.org/data/2.5/weather?q=ilo,pe&units=imperial) has been processed
# city not found : tabiauea, ki was skipped.
# 1160939 : iranshahr, ir, (https://api.openweathermap.org/data/2.5/weather?q=iranshahr,ir&units=imperial) has been processed
# 1314759 : lashio, mm, (https://api.openweathermap.org/data/2.5/weather?q=lashio,mm&units=imperial) has been processed
# 3654410 : manta, ec, (https://api.openweathermap.org/data/2.5/weather?q=manta,ec&units=imperial) has been processed
# 3465342 : puerto quijarro, bo, (https://api.openweathermap.org/data/2.5/weather?q=puerto quijarro,bo&units=imperial) has been processed
# 3492520 : tamayo, do, (https://api.openweathermap.org/data/2.5/weather?q=tamayo,do&units=imperial) has been processed
# 1028918 : pemba, mz, (https://api.openweathermap.org/data/2.5/weather?q=pemba,mz&units=imperial) has been processed
# 1039536 : maxixe, mz, (https://api.openweathermap.org/data/2.5/weather?q=maxixe,mz&units=imperial) has been processed
# 287286 : muscat, om, (https://api.openweathermap.org/data/2.5/weather?q=muscat,om&units=imperial) has been processed
# 899274 : samfya, zm, (https://api.openweathermap.org/data/2.5/weather?q=samfya,zm&units=imperial) has been processed
# 3448903 : sao joao da barra, br, (https://api.openweathermap.org/data/2.5/weather?q=sao joao da barra,br&units=imperial) has been processed
# 498537 : sarmanovo, ru, (https://api.openweathermap.org/data/2.5/weather?q=sarmanovo,ru&units=imperial) has been processed
# 1786720 : yigou, cn, (https://api.openweathermap.org/data/2.5/weather?q=yigou,cn&units=imperial) has been processed
# 3391412 : portel, br, (https://api.openweathermap.org/data/2.5/weather?q=portel,br&units=imperial) has been processed
# 6111862 : port hardy, ca, (https://api.openweathermap.org/data/2.5/weather?q=port hardy,ca&units=imperial) has been processed
# ________________________________________________________________
# 81 rows dropped due to error(s) retrieving data. 549 cities remaining.
# ________________________________________________________________
# Weather data has been loaded for 549 cities of 500 cities required.

# %%
# Save collected data
cities.to_csv("city_weather_data.csv", encoding='utf-8')

# %%
cm = plt.cm.get_cmap('coolwarm')

plt.scatter(cities["Latitude"],cities["Temperature"] 
, s=50, c=cities["Temperature"], cmap=cm, alpha=.7, edgecolor="gray")

plt.title(f"City Latitude vs Max Temperature {datetime.utcfromtimestamp(cities['Time'].mean()).strftime('%Y-%m-%d %H:%M:%S')}")
plt.xlabel("Lattitude")
plt.ylabel("Max Temperature (Fahrenheit)")

plt.grid()
          
# Save Figure to local dir
plt.savefig('Lat_vs_Max_Temp.png')

plt.show()

# %%
cm = plt.cm.get_cmap('coolwarm')

plt.scatter(cities["Latitude"],cities["Humidity"] 
, s=50, c=cities["Humidity"], cmap=cm, alpha=.7, edgecolor="gray")

plt.title(f"City Latitude vs Humidity {datetime.utcfromtimestamp(cities['Time'].mean()).strftime('%Y-%m-%d %H:%M:%S')}")
plt.xlabel("Lattitude")
plt.ylabel("Humidity (Percent)")

plt.grid()
          
# Save Figure to local dir
plt.savefig('Lat_vs_Humidity.png')
          
plt.show()

# %%
cm = plt.cm.get_cmap('Blues')

plt.scatter(cities["Latitude"],cities["Cloudiness"] 
, s=50, c=100 - cities["Cloudiness"], cmap=cm, alpha=.7, edgecolor="gray")

plt.title(f"City Latitude vs Cloudiness {datetime.utcfromtimestamp(cities['Time'].mean()).strftime('%Y-%m-%d %H:%M:%S')}")
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness (Percent)")

plt.grid()
          
# Save Figure to local dir
plt.savefig('Lat_vs_Cloudiness.png')
          
plt.show()

# %%
cm = plt.cm.get_cmap('winter')

plt.scatter(cities["Latitude"],cities["Wind Speed"] 
, s=50, c=200-cities["Wind Speed"], cmap=cm, alpha=.7, edgecolor="gray")

plt.title(f"City Latitude vs Wind Speed {datetime.utcfromtimestamp(cities['Time'].mean()).strftime('%Y-%m-%d %H:%M:%S')}")
plt.xlabel("Lattitude")
plt.ylabel("Wind Speed (MPH)")

plt.grid()
          
# Save Figure to local dir
plt.savefig('Lat_vs_Wind_Speed.png')
          
plt.show()
